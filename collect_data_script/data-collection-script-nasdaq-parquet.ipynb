# %%
import os
import contextlib
import logging
import pandas as pd
import polars as pl
import yfinance as yf
from pathlib import Path

# %%
# ==================== CẤU HÌNH & HẰNG SỐ ====================
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s: %(message)s')

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"

RAW_DIR = DATA_DIR / "raw"
METADATA_DIR = DATA_DIR / "metadata"

DIRECTORIES = [RAW_DIR, METADATA_DIR]

NASDAQ_URL = "http://www.nasdaqtrader.com/dynamic/SymDir/nasdaqtraded.txt"

# %%
# ==================== CÁC HÀM XỬ LÝ ====================
def setup_directories(dirs: list):
    """Tạo cấu trúc thư mục làm việc."""
    for d in dirs:
        d.mkdir(parents=True, exist_ok=True)
    logging.info("Đã thiết lập xong cấu trúc thư mục Data Lake.")

def fetch_and_clean_metadata() -> pd.DataFrame:
    """Tải và làm sạch nhẹ danh sách mã chứng khoán từ NASDAQ."""
    logging.info("Đang tải danh sách symbols từ NASDAQ...")
    try:
        dirty_data = pd.read_csv(NASDAQ_URL, sep='|')
        clean_data = dirty_data[dirty_data['Test Issue'] == 'N'].copy()
        clean_data = clean_data[~clean_data['NASDAQ Symbol'].str.contains(r'[-=\.\^]', regex=True, na=False)]
        return clean_data
    except Exception as e:
        logging.error(f"Lỗi khi lấy metadata từ NASDAQ: {e}")
        return pd.DataFrame()

# %%
# ==================== MAIN EXECUTION ====================
if __name__ == "__main__":
    setup_directories(DIRECTORIES)
    meta_df = fetch_and_clean_metadata()
    
    if meta_df.empty:
        logging.error("Không tải được metadata. Hủy quá trình.")
        exit(1)
        
    symbols = meta_df['NASDAQ Symbol'].tolist()
    symbol_type_map = dict(zip(meta_df['NASDAQ Symbol'], meta_df['ETF']))

    valid_symbols = []

    logging.info(f"Bắt đầu tải {len(symbols)} symbols. Ghi trực tiếp 1 file/symbol vào Raw...")
    
    # Chặn log rác từ thư viện yfinance
    with open(os.devnull, 'w') as devnull:
        with contextlib.redirect_stdout(devnull):
            for symbol in symbols:
                try:
                    # 1. Kéo dữ liệu gốc bằng Pandas
                    df_pd = yf.download(symbol, period='max', progress=False)
                    if df_pd.empty: 
                        continue
                    
                    # Fix cấu trúc MultiIndex của yfinance trả về
                    if isinstance(df_pd.columns, pd.MultiIndex):
                        df_pd.columns = df_pd.columns.droplevel(1)
                    
                    df_pd = df_pd.reset_index()
                    if df_pd['Date'].dt.tz is not None:
                        df_pd['Date'] = df_pd['Date'].dt.tz_localize(None)

                    # 2. Đưa sang Polars để cấu trúc lại Schema
                    df = pl.from_pandas(df_pd)
                    cols = df.columns
                    asset_type = "etfs" if symbol_type_map.get(symbol) == 'Y' else "stocks"

                    # Đảm bảo cấu trúc cột đồng nhất cho mọi file
                    if "Adj Close" not in cols:
                        df = df.with_columns(pl.col("Close").alias("Adj Close"))
                    if "Volume" not in cols:
                        df = df.with_columns(pl.lit(None, dtype=pl.Int64).alias("Volume"))
                        
                    # Ép kiểu dữ liệu (Data Type Contract) để tầng ETL sau không bị vấp
                    df = df.with_columns([
                        pl.lit(symbol).alias("Symbol"),
                        pl.lit(asset_type).alias("Asset_Type"),
                        pl.col("Date").cast(pl.Datetime, strict=False).dt.date().alias("Date"),
                        pl.col("Date").dt.year().alias("Year"), # Vẫn giữ cột Year để sau này Transform dùng chia Partition
                        pl.col("Open").cast(pl.Float64, strict=False),
                        pl.col("High").cast(pl.Float64, strict=False),
                        pl.col("Low").cast(pl.Float64, strict=False),
                        pl.col("Close").cast(pl.Float64, strict=False),
                        pl.col("Adj Close").cast(pl.Float64, strict=False),
                        pl.col("Volume").cast(pl.Int64, strict=False)
                    ]).select([
                        "Date", "Year", "Symbol", "Asset_Type", 
                        "Open", "High", "Low", "Close", "Adj Close", "Volume"
                    ])
                    
                    # 3. LOAD (Ghi trực tiếp file ra disk, giải phóng RAM ngay lập tức)
                    output_file = RAW_DIR / f"{symbol}.parquet"
                    df.write_parquet(output_file, use_pyarrow=True)
                    
                    valid_symbols.append(symbol)

                except Exception as e:
                    logging.warning(f"Lỗi khi tải {symbol}: {e}")
                    continue

    # 4. Ghi lại danh sách các mã đã tải thành công (Metadata)
    if valid_symbols:
        logging.info("Đang cập nhật Metadata các mã thành công...")
        valid_meta = meta_df[meta_df['NASDAQ Symbol'].isin(valid_symbols)]
        valid_meta[valid_meta['ETF'] == 'N'].to_csv(METADATA_DIR / "symbols_stock.csv", index=False)
        valid_meta[valid_meta['ETF'] == 'Y'].to_csv(METADATA_DIR / "symbols_etf.csv", index=False)

    logging.info(f"Hoàn tất! Đã tải thành công {len(valid_symbols)} file vào thư mục Raw.")
# Out:
# 2026-07-09 18:42:15,477 - INFO: Đã thiết lập xong cấu trúc thư mục Data Lake.
# 2026-07-09 18:42:15,479 - INFO: Đang tải danh sách symbols từ NASDAQ...
# 2026-07-09 18:42:18,063 - INFO: Bắt đầu tải 12496 symbols. Ghi trực tiếp 1 file/symbol vào Raw...
# 2026-07-09 18:42:24,966 - ERROR: AACBR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:24,976 - ERROR:
# 1 Failed download:
# 2026-07-09 18:42:24,977 - ERROR: ['AACBR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:26,943 - ERROR: AACOW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:26,956 - ERROR:
# 1 Failed download:
# 2026-07-09 18:42:26,956 - ERROR: ['AACOW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:27,703 - ERROR: AACPW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:27,716 - ERROR:
# 1 Failed download:
# 2026-07-09 18:42:27,721 - ERROR: ['AACPW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:51,700 - ERROR: ACAAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:42:51,707 - ERROR:
# 1 Failed download:
# 2026-07-09 18:42:51,710 - ERROR: ['ACAAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:00,889 - ERROR: HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ACHR+"}}}
# 2026-07-09 18:43:01,047 - ERROR: $ACHR+: possibly delisted; no timezone found
# 2026-07-09 18:43:01,057 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:01,073 - ERROR: ['ACHR+']: possibly delisted; no timezone found
# 2026-07-09 18:43:19,708 - ERROR: ADACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:19,719 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:19,720 - ERROR: ['ADACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:36,740 - ERROR: AEAQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:36,748 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:36,750 - ERROR: ['AEAQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:47,928 - ERROR: AESP: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:47,934 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:47,934 - ERROR: ['AESP']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:48,128 - ERROR: AESPR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:48,137 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:48,137 - ERROR: ['AESPR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:48,483 - ERROR: AESPW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:48,495 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:48,496 - ERROR: ['AESPW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:54,962 - ERROR: AFJKR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:43:54,970 - ERROR:
# 1 Failed download:
# 2026-07-09 18:43:54,970 - ERROR: ['AFJKR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:44:56,181 - ERROR: ALISR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:44:56,187 - ERROR:
# 1 Failed download:
# 2026-07-09 18:44:56,188 - ERROR: ['ALISR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:05,425 - ERROR: ALOVW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:05,436 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:05,437 - ERROR: ['ALOVW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:06,435 - ERROR: ALPX: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:06,443 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:06,443 - ERROR: ['ALPX']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:06,595 - ERROR: ALPXR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:06,600 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:06,600 - ERROR: ['ALPXR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:07,077 - ERROR: ALPXW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:07,085 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:07,086 - ERROR: ['ALPXW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:11,633 - ERROR: HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ALUB+"}}}
# 2026-07-09 18:45:11,788 - ERROR: $ALUB+: possibly delisted; no timezone found
# 2026-07-09 18:45:11,805 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:11,806 - ERROR: ['ALUB+']: possibly delisted; no timezone found
# 2026-07-09 18:45:28,448 - ERROR: AMPGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:28,456 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:28,459 - ERROR: ['AMPGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:28,637 - ERROR: AMPGZ: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:28,642 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:28,645 - ERROR: ['AMPGZ']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:30,195 - ERROR: $AMPX+: possibly delisted; no timezone found
# 2026-07-09 18:45:30,213 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:30,214 - ERROR: ['AMPX+']: possibly delisted; no timezone found
# 2026-07-09 18:45:38,777 - ERROR: AMZG: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:45:38,788 - ERROR:
# 1 Failed download:
# 2026-07-09 18:45:38,788 - ERROR: ['AMZG']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:00,882 - ERROR: APACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:00,888 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:00,889 - ERROR: ['APACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:08,586 - ERROR: APMCR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:08,628 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:08,629 - ERROR: ['APMCR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:09,018 - ERROR: APMI: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:09,047 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:09,050 - ERROR: ['APMI']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:16,057 - ERROR: APURR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:16,065 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:16,066 - ERROR: ['APURR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:24,151 - ERROR: ARCIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:24,166 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:24,167 - ERROR: ['ARCIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:24,946 - ERROR: ARCLW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:24,959 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:24,961 - ERROR: ['ARCLW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:45,885 - ERROR: ARTCW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:46:45,903 - ERROR:
# 1 Failed download:
# 2026-07-09 18:46:45,904 - ERROR: ['ARTCW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:47:03,942 - ERROR: ASPCR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:47:03,947 - ERROR:
# 1 Failed download:
# 2026-07-09 18:47:03,949 - ERROR: ['ASPCR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:07,631 - ERROR: AXINR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:07,634 - ERROR:
# 1 Failed download:
# 2026-07-09 18:48:07,635 - ERROR: ['AXINR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:11,160 - ERROR: AXTC: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:11,171 - ERROR:
# 1 Failed download:
# 2026-07-09 18:48:11,172 - ERROR: ['AXTC']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:24,073 - ERROR: BACCR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:24,082 - ERROR:
# 1 Failed download:
# 2026-07-09 18:48:24,083 - ERROR: ['BACCR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:40,882 - ERROR: $BBAI+: possibly delisted; no timezone found
# 2026-07-09 18:48:40,897 - ERROR:
# 1 Failed download:
# 2026-07-09 18:48:40,898 - ERROR: ['BBAI+']: possibly delisted; no timezone found
# 2026-07-09 18:48:43,770 - ERROR: $BBBY+: possibly delisted; no timezone found
# 2026-07-09 18:48:43,790 - ERROR:
# 1 Failed download:
# 2026-07-09 18:48:43,792 - ERROR: ['BBBY+']: possibly delisted; no timezone found
# 2026-07-09 18:48:56,148 - ERROR: BBUL: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:48:56,159 - ERROR:
# 1 Failed download:
# 2026-07-09 18:48:56,161 - ERROR: ['BBUL']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:49:15,294 - ERROR: $BCSS+: possibly delisted; no timezone found
# 2026-07-09 18:49:15,297 - ERROR:
# 1 Failed download:
# 2026-07-09 18:49:15,306 - ERROR: ['BCSS+']: possibly delisted; no timezone found
# 2026-07-09 18:49:16,050 - ERROR: BCTXL: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:49:16,063 - ERROR:
# 1 Failed download:
# 2026-07-09 18:49:16,065 - ERROR: ['BCTXL']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:49:28,027 - ERROR: BEAGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:49:28,034 - ERROR:
# 1 Failed download:
# 2026-07-09 18:49:28,035 - ERROR: ['BEAGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:49:29,710 - ERROR: $BEBE+: possibly delisted; no timezone found
# 2026-07-09 18:49:29,716 - ERROR:
# 1 Failed download:
# 2026-07-09 18:49:29,719 - ERROR: ['BEBE+']: possibly delisted; no timezone found
# 2026-07-09 18:49:38,887 - ERROR: $BESS+: possibly delisted; no timezone found
# 2026-07-09 18:49:38,916 - ERROR:
# 1 Failed download:
# 2026-07-09 18:49:38,918 - ERROR: ['BESS+']: possibly delisted; no timezone found
# 2026-07-09 18:50:23,588 - ERROR: BHAVR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:50:23,596 - ERROR:
# 1 Failed download:
# 2026-07-09 18:50:23,597 - ERROR: ['BHAVR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:50:45,700 - ERROR: $BIII+: possibly delisted; no timezone found
# 2026-07-09 18:50:45,732 - ERROR:
# 1 Failed download:
# 2026-07-09 18:50:45,734 - ERROR: ['BIII+']: possibly delisted; no timezone found
# 2026-07-09 18:51:06,520 - ERROR: BKHAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:51:06,533 - ERROR:
# 1 Failed download:
# 2026-07-09 18:51:06,535 - ERROR: ['BKHAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:51:08,332 - ERROR: $BKKT+: possibly delisted; no timezone found
# 2026-07-09 18:51:08,343 - ERROR:
# 1 Failed download:
# 2026-07-09 18:51:08,344 - ERROR: ['BKKT+']: possibly delisted; no timezone found
# 2026-07-09 18:51:12,240 - ERROR: $BKSY+: possibly delisted; no timezone found
# 2026-07-09 18:51:12,254 - ERROR:
# 1 Failed download:
# 2026-07-09 18:51:12,255 - ERROR: ['BKSY+']: possibly delisted; no timezone found
# 2026-07-09 18:51:25,330 - ERROR: BLRKW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:51:25,341 - ERROR:
# 1 Failed download:
# 2026-07-09 18:51:25,342 - ERROR: ['BLRKW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:51:49,876 - ERROR: BNCWZ: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:51:49,887 - ERROR:
# 1 Failed download:
# 2026-07-09 18:51:49,888 - ERROR: ['BNCWZ']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:14,312 - ERROR: BPACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:14,319 - ERROR:
# 1 Failed download:
# 2026-07-09 18:52:14,320 - ERROR: ['BPACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:24,417 - ERROR: BREZR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:24,422 - ERROR:
# 1 Failed download:
# 2026-07-09 18:52:24,424 - ERROR: ['BREZR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:27,482 - ERROR: BRKL: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:27,492 - ERROR:
# 1 Failed download:
# 2026-07-09 18:52:27,492 - ERROR: ['BRKL']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:36,648 - ERROR: BRUNW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:36,676 - ERROR:
# 1 Failed download:
# 2026-07-09 18:52:36,679 - ERROR: ['BRUNW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:39,034 - ERROR: BSAAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:52:39,047 - ERROR:
# 1 Failed download:
# 2026-07-09 18:52:39,048 - ERROR: ['BSAAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:53:32,436 - ERROR: $BWIV+: possibly delisted; no timezone found
# 2026-07-09 18:53:32,464 - ERROR:
# 1 Failed download:
# 2026-07-09 18:53:32,465 - ERROR: ['BWIV+']: possibly delisted; no timezone found
# 2026-07-09 18:53:34,612 - ERROR: $BWQG: possibly delisted; no timezone found
# 2026-07-09 18:53:34,635 - ERROR:
# 1 Failed download:
# 2026-07-09 18:53:34,636 - ERROR: ['BWQG']: possibly delisted; no timezone found
# 2026-07-09 18:53:56,867 - ERROR: CAIIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:53:56,904 - ERROR:
# 1 Failed download:
# 2026-07-09 18:53:56,904 - ERROR: ['CAIIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:54:07,820 - ERROR: CAQUW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:54:07,824 - ERROR:
# 1 Failed download:
# 2026-07-09 18:54:07,826 - ERROR: ['CAQUW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:54:36,463 - ERROR: CCAQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:54:36,471 - ERROR:
# 1 Failed download:
# 2026-07-09 18:54:36,475 - ERROR: ['CCAQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:54:54,250 - ERROR: CCXIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:54:54,256 - ERROR:
# 1 Failed download:
# 2026-07-09 18:54:54,257 - ERROR: ['CCXIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:55:40,209 - ERROR: CHARR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:55:40,223 - ERROR:
# 1 Failed download:
# 2026-07-09 18:55:40,224 - ERROR: ['CHARR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:55:51,685 - ERROR: CHPGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:55:51,699 - ERROR:
# 1 Failed download:
# 2026-07-09 18:55:51,701 - ERROR: ['CHPGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:56:21,387 - ERROR: CIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:56:21,393 - ERROR:
# 1 Failed download:
# 2026-07-09 18:56:21,394 - ERROR: ['CIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:56:41,199 - ERROR: $CLBR+: possibly delisted; no timezone found
# 2026-07-09 18:56:41,219 - ERROR:
# 1 Failed download:
# 2026-07-09 18:56:41,220 - ERROR: ['CLBR+']: possibly delisted; no timezone found
# 2026-07-09 18:57:34,929 - ERROR: CMIIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:57:34,944 - ERROR:
# 1 Failed download:
# 2026-07-09 18:57:34,946 - ERROR: ['CMIIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:13,137 - ERROR: COLAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:13,184 - ERROR:
# 1 Failed download:
# 2026-07-09 18:58:13,185 - ERROR: ['COLAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:23,657 - ERROR: $COPL+: possibly delisted; no timezone found
# 2026-07-09 18:58:23,672 - ERROR:
# 1 Failed download:
# 2026-07-09 18:58:23,674 - ERROR: ['COPL+']: possibly delisted; no timezone found
# 2026-07-09 18:58:24,813 - ERROR: $COPR+: possibly delisted; no timezone found
# 2026-07-09 18:58:24,829 - ERROR:
# 1 Failed download:
# 2026-07-09 18:58:24,830 - ERROR: ['COPR+']: possibly delisted; no timezone found
# 2026-07-09 18:58:53,859 - ERROR: CRACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:53,868 - ERROR:
# 1 Failed download:
# 2026-07-09 18:58:53,869 - ERROR: ['CRACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:55,506 - ERROR: CRANR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:55,522 - ERROR:
# 1 Failed download:
# 2026-07-09 18:58:55,523 - ERROR: ['CRANR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:56,577 - ERROR: CRAQR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:58:56,591 - ERROR:
# 1 Failed download:
# 2026-07-09 18:58:56,593 - ERROR: ['CRAQR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:59:29,641 - ERROR: CSHRW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:59:29,652 - ERROR:
# 1 Failed download:
# 2026-07-09 18:59:29,653 - ERROR: ['CSHRW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:59:39,623 - ERROR: CTAAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 18:59:39,627 - ERROR:
# 1 Failed download:
# 2026-07-09 18:59:39,629 - ERROR: ['CTAAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:00:44,884 - ERROR: CXIIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:00:44,896 - ERROR:
# 1 Failed download:
# 2026-07-09 19:00:44,898 - ERROR: ['CXIIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:01:30,090 - ERROR: DBCAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:01:30,098 - ERROR:
# 1 Failed download:
# 2026-07-09 19:01:30,099 - ERROR: ['DBCAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:07,255 - ERROR: DFNSW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:07,261 - ERROR:
# 1 Failed download:
# 2026-07-09 19:03:07,292 - ERROR: ['DFNSW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:34,537 - ERROR: DISK: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:34,552 - ERROR:
# 1 Failed download:
# 2026-07-09 19:03:34,553 - ERROR: ['DISK']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:54,083 - ERROR: DMAAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:54,089 - ERROR:
# 1 Failed download:
# 2026-07-09 19:03:54,089 - ERROR: ['DMAAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:56,886 - ERROR: DMIIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:03:56,890 - ERROR:
# 1 Failed download:
# 2026-07-09 19:03:56,891 - ERROR: ['DMIIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:04:31,128 - ERROR: $DRVR: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:04:31,141 - ERROR:
# 1 Failed download:
# 2026-07-09 19:04:31,142 - ERROR: ['DRVR']: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:04:31,767 - ERROR: DSACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:04:31,796 - ERROR:
# 1 Failed download:
# 2026-07-09 19:04:31,798 - ERROR: ['DSACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:04:39,547 - ERROR: $DSX+: possibly delisted; no timezone found
# 2026-07-09 19:04:39,558 - ERROR:
# 1 Failed download:
# 2026-07-09 19:04:39,559 - ERROR: ['DSX+']: possibly delisted; no timezone found
# 2026-07-09 19:04:46,509 - ERROR: DTSQR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:04:46,520 - ERROR:
# 1 Failed download:
# 2026-07-09 19:04:46,520 - ERROR: ['DTSQR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:05:24,674 - ERROR: DYNCW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:05:24,687 - ERROR:
# 1 Failed download:
# 2026-07-09 19:05:24,687 - ERROR: ['DYNCW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:06:47,557 - ERROR: EGHAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:06:47,564 - ERROR:
# 1 Failed download:
# 2026-07-09 19:06:47,565 - ERROR: ['EGHAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:07:24,292 - ERROR: EMISR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:07:24,327 - ERROR:
# 1 Failed download:
# 2026-07-09 19:07:24,328 - ERROR: ['EMISR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:07:40,617 - ERROR: ENRDW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:07:40,631 - ERROR:
# 1 Failed download:
# 2026-07-09 19:07:40,633 - ERROR: ['ENRDW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:07:48,292 - ERROR: $EONR+: possibly delisted; no timezone found
# 2026-07-09 19:07:48,322 - ERROR:
# 1 Failed download:
# 2026-07-09 19:07:48,322 - ERROR: ['EONR+']: possibly delisted; no timezone found
# 2026-07-09 19:07:49,432 - ERROR: EOSER: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:07:49,444 - ERROR:
# 1 Failed download:
# 2026-07-09 19:07:49,445 - ERROR: ['EOSER']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:13,535 - ERROR: ERNAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:13,544 - ERROR:
# 1 Failed download:
# 2026-07-09 19:08:13,545 - ERROR: ['ERNAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:22,732 - ERROR: ESLAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:22,736 - ERROR:
# 1 Failed download:
# 2026-07-09 19:08:22,738 - ERROR: ['ESLAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:42,308 - ERROR: $ETSS+: possibly delisted; no timezone found
# 2026-07-09 19:08:42,315 - ERROR:
# 1 Failed download:
# 2026-07-09 19:08:42,315 - ERROR: ['ETSS+']: possibly delisted; no timezone found
# 2026-07-09 19:08:55,287 - ERROR: EURKR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:55,304 - ERROR:
# 1 Failed download:
# 2026-07-09 19:08:55,305 - ERROR: ['EURKR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:08:58,928 - ERROR: $EVAC+: possibly delisted; no timezone found
# 2026-07-09 19:08:58,963 - ERROR:
# 1 Failed download:
# 2026-07-09 19:08:58,967 - ERROR: ['EVAC+']: possibly delisted; no timezone found
# 2026-07-09 19:09:01,492 - ERROR: $EVEX+: possibly delisted; no timezone found
# 2026-07-09 19:09:01,499 - ERROR:
# 1 Failed download:
# 2026-07-09 19:09:01,501 - ERROR: ['EVEX+']: possibly delisted; no timezone found
# 2026-07-09 19:09:46,461 - ERROR: FACWW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:09:46,476 - ERROR:
# 1 Failed download:
# 2026-07-09 19:09:46,478 - ERROR: ['FACWW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:10:02,333 - ERROR: $FBYDP: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:10:02,339 - ERROR:
# 1 Failed download:
# 2026-07-09 19:10:02,340 - ERROR: ['FBYDP']: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:10:13,933 - ERROR: $FCRS+: possibly delisted; no timezone found
# 2026-07-09 19:10:13,950 - ERROR:
# 1 Failed download:
# 2026-07-09 19:10:13,952 - ERROR: ['FCRS+']: possibly delisted; no timezone found
# 2026-07-09 19:10:43,425 - ERROR: FERAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:10:43,440 - ERROR:
# 1 Failed download:
# 2026-07-09 19:10:43,442 - ERROR: ['FERAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:10:57,124 - ERROR: FGIIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:10:57,135 - ERROR:
# 1 Failed download:
# 2026-07-09 19:10:57,136 - ERROR: ['FGIIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:10:58,315 - ERROR: FGMCR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:10:58,325 - ERROR:
# 1 Failed download:
# 2026-07-09 19:10:58,332 - ERROR: ['FGMCR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:11:10,085 - ERROR: $FINA: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:11:10,092 - ERROR:
# 1 Failed download:
# 2026-07-09 19:11:10,093 - ERROR: ['FINA']: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:11:51,468 - ERROR: $FLYX+: possibly delisted; no timezone found
# 2026-07-09 19:11:51,478 - ERROR:
# 1 Failed download:
# 2026-07-09 19:11:51,487 - ERROR: ['FLYX+']: possibly delisted; no timezone found
# 2026-07-09 19:11:52,160 - ERROR: FMACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:11:52,192 - ERROR:
# 1 Failed download:
# 2026-07-09 19:11:52,194 - ERROR: ['FMACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:12:43,521 - ERROR: FSHPR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:12:43,556 - ERROR:
# 1 Failed download:
# 2026-07-09 19:12:43,557 - ERROR: ['FSHPR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:12:47,937 - ERROR: $FSPC: possibly delisted; no timezone found
# 2026-07-09 19:12:47,948 - ERROR:
# 1 Failed download:
# 2026-07-09 19:12:47,949 - ERROR: ['FSPC']: possibly delisted; no timezone found
# 2026-07-09 19:13:00,422 - ERROR: FTHAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:13:00,444 - ERROR:
# 1 Failed download:
# 2026-07-09 19:13:00,445 - ERROR: ['FTHAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:13:10,929 - ERROR: $FTW+: possibly delisted; no timezone found
# 2026-07-09 19:13:10,935 - ERROR:
# 1 Failed download:
# 2026-07-09 19:13:10,936 - ERROR: ['FTW+']: possibly delisted; no timezone found
# 2026-07-09 19:13:28,149 - ERROR: FXACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:13:28,165 - ERROR:
# 1 Failed download:
# 2026-07-09 19:13:28,168 - ERROR: ['FXACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:13:57,041 - ERROR: GCGRW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:13:57,073 - ERROR:
# 1 Failed download:
# 2026-07-09 19:13:57,074 - ERROR: ['GCGRW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:14:00,655 - ERROR: $GCTS+: possibly delisted; no timezone found
# 2026-07-09 19:14:00,663 - ERROR:
# 1 Failed download:
# 2026-07-09 19:14:00,664 - ERROR: ['GCTS+']: possibly delisted; no timezone found
# 2026-07-09 19:14:48,346 - ERROR: GIWWR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:14:48,352 - ERROR:
# 1 Failed download:
# 2026-07-09 19:14:48,353 - ERROR: ['GIWWR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:14:48,880 - ERROR: GIXXR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:14:48,894 - ERROR:
# 1 Failed download:
# 2026-07-09 19:14:48,895 - ERROR: ['GIXXR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:15:00,446 - ERROR: GLNDW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:15:00,451 - ERROR:
# 1 Failed download:
# 2026-07-09 19:15:00,452 - ERROR: ['GLNDW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:15:11,236 - ERROR: $GME+: possibly delisted; no timezone found
# 2026-07-09 19:15:11,250 - ERROR:
# 1 Failed download:
# 2026-07-09 19:15:11,251 - ERROR: ['GME+']: possibly delisted; no timezone found
# 2026-07-09 19:16:06,112 - ERROR: GPACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:06,116 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:06,118 - ERROR: ['GPACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:16,294 - ERROR: $GRAF+: possibly delisted; no timezone found
# 2026-07-09 19:16:16,304 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:16,305 - ERROR: ['GRAF+']: possibly delisted; no timezone found
# 2026-07-09 19:16:22,391 - ERROR: GRMLW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:22,399 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:22,399 - ERROR: ['GRMLW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:27,354 - ERROR: $GROY+: possibly delisted; no timezone found
# 2026-07-09 19:16:27,361 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:27,362 - ERROR: ['GROY+']: possibly delisted; no timezone found
# 2026-07-09 19:16:41,198 - ERROR: GSRVR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:41,203 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:41,204 - ERROR: ['GSRVR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:46,925 - ERROR: GTERR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:46,942 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:46,943 - ERROR: ['GTERR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:54,534 - ERROR: GUACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:16:54,540 - ERROR:
# 1 Failed download:
# 2026-07-09 19:16:54,540 - ERROR: ['GUACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:16,187 - ERROR: HACQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:16,192 - ERROR:
# 1 Failed download:
# 2026-07-09 19:17:16,192 - ERROR: ['HACQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:29,090 - ERROR: HAVAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:29,110 - ERROR:
# 1 Failed download:
# 2026-07-09 19:17:29,111 - ERROR: ['HAVAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:37,059 - ERROR: HCACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:37,074 - ERROR:
# 1 Failed download:
# 2026-07-09 19:17:37,080 - ERROR: ['HCACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:39,250 - ERROR: HCICR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:39,262 - ERROR:
# 1 Failed download:
# 2026-07-09 19:17:39,263 - ERROR: ['HCICR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:47,548 - ERROR: HDRNW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:17:47,556 - ERROR:
# 1 Failed download:
# 2026-07-09 19:17:47,566 - ERROR: ['HDRNW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:18:21,436 - ERROR: $HLLY+: possibly delisted; no timezone found
# 2026-07-09 19:18:21,447 - ERROR:
# 1 Failed download:
# 2026-07-09 19:18:21,448 - ERROR: ['HLLY+']: possibly delisted; no timezone found
# 2026-07-09 19:19:11,397 - ERROR: HVIIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:11,411 - ERROR:
# 1 Failed download:
# 2026-07-09 19:19:11,411 - ERROR: ['HVIIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:30,091 - ERROR: IACOW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:30,102 - ERROR:
# 1 Failed download:
# 2026-07-09 19:19:30,103 - ERROR: ['IACOW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:30,712 - ERROR: IACQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:30,723 - ERROR:
# 1 Failed download:
# 2026-07-09 19:19:30,725 - ERROR: ['IACQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:36,736 - ERROR: $IAUX+: possibly delisted; no timezone found
# 2026-07-09 19:19:36,742 - ERROR:
# 1 Failed download:
# 2026-07-09 19:19:36,743 - ERROR: ['IAUX+']: possibly delisted; no timezone found
# 2026-07-09 19:19:37,132 - ERROR: IBACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:19:37,147 - ERROR:
# 1 Failed download:
# 2026-07-09 19:19:37,148 - ERROR: ['IBACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:20:10,730 - ERROR: IDACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:20:10,745 - ERROR:
# 1 Failed download:
# 2026-07-09 19:20:10,750 - ERROR: ['IDACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:20:21,514 - ERROR: IEAGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:20:21,525 - ERROR:
# 1 Failed download:
# 2026-07-09 19:20:21,544 - ERROR: ['IEAGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:20:59,717 - ERROR: ILLRW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:20:59,730 - ERROR:
# 1 Failed download:
# 2026-07-09 19:20:59,733 - ERROR: ['ILLRW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:00,331 - ERROR: ILLUW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:00,337 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:00,337 - ERROR: ['ILLUW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:15,167 - ERROR: INACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:15,176 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:15,177 - ERROR: ['INACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:25,281 - ERROR: $INFQ+: possibly delisted; no timezone found
# 2026-07-09 19:21:25,297 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:25,299 - ERROR: ['INFQ+']: possibly delisted; no timezone found
# 2026-07-09 19:21:45,242 - ERROR: $IONQ+: possibly delisted; no timezone found
# 2026-07-09 19:21:45,256 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:45,257 - ERROR: ['IONQ+']: possibly delisted; no timezone found
# 2026-07-09 19:21:52,920 - ERROR: IPCXR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:52,929 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:52,930 - ERROR: ['IPCXR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:53,814 - ERROR: IPEXR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:53,820 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:53,822 - ERROR: ['IPEXR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:54,833 - ERROR: IPFXW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:21:54,841 - ERROR:
# 1 Failed download:
# 2026-07-09 19:21:54,842 - ERROR: ['IPFXW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:22:02,710 - ERROR: IQMXW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:22:02,718 - ERROR:
# 1 Failed download:
# 2026-07-09 19:22:02,724 - ERROR: ['IQMXW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:22:06,190 - ERROR: $IRAB+: possibly delisted; no timezone found
# 2026-07-09 19:22:06,207 - ERROR:
# 1 Failed download:
# 2026-07-09 19:22:06,208 - ERROR: ['IRAB+']: possibly delisted; no timezone found
# 2026-07-09 19:22:08,479 - ERROR: IRHOR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:22:08,491 - ERROR:
# 1 Failed download:
# 2026-07-09 19:22:08,494 - ERROR: ['IRHOR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:22:28,137 - ERROR: ITHAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:22:28,144 - ERROR:
# 1 Failed download:
# 2026-07-09 19:22:28,145 - ERROR: ['ITHAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:23:50,516 - ERROR: $JOBY+: possibly delisted; no timezone found
# 2026-07-09 19:23:50,532 - ERROR:
# 1 Failed download:
# 2026-07-09 19:23:50,533 - ERROR: ['JOBY+']: possibly delisted; no timezone found
# 2026-07-09 19:24:23,510 - ERROR: KBONW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:23,517 - ERROR:
# 1 Failed download:
# 2026-07-09 19:24:23,521 - ERROR: ['KBONW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:27,049 - ERROR: $KCAC+: possibly delisted; no timezone found
# 2026-07-09 19:24:27,063 - ERROR:
# 1 Failed download:
# 2026-07-09 19:24:27,064 - ERROR: ['KCAC+']: possibly delisted; no timezone found
# 2026-07-09 19:24:28,417 - ERROR: KCHVR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:28,428 - ERROR:
# 1 Failed download:
# 2026-07-09 19:24:28,428 - ERROR: ['KCHVR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:39,350 - ERROR: KEYYW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:39,382 - ERROR:
# 1 Failed download:
# 2026-07-09 19:24:39,384 - ERROR: ['KEYYW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:41,029 - ERROR: KFIIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:24:41,038 - ERROR:
# 1 Failed download:
# 2026-07-09 19:24:41,039 - ERROR: ['KFIIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:25:14,885 - ERROR: $KPET+: possibly delisted; no timezone found
# 2026-07-09 19:25:14,903 - ERROR:
# 1 Failed download:
# 2026-07-09 19:25:14,906 - ERROR: ['KPET+']: possibly delisted; no timezone found
# 2026-07-09 19:25:18,267 - ERROR: KRAQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:25:18,287 - ERROR:
# 1 Failed download:
# 2026-07-09 19:25:18,287 - ERROR: ['KRAQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:25:24,890 - ERROR: $KRSP+: possibly delisted; no timezone found
# 2026-07-09 19:25:24,896 - ERROR:
# 1 Failed download:
# 2026-07-09 19:25:24,898 - ERROR: ['KRSP+']: possibly delisted; no timezone found
# 2026-07-09 19:25:33,270 - ERROR: KTWOR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:25:33,298 - ERROR:
# 1 Failed download:
# 2026-07-09 19:25:33,303 - ERROR: ['KTWOR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:25:57,653 - ERROR: LCCCR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:25:57,665 - ERROR:
# 1 Failed download:
# 2026-07-09 19:25:57,666 - ERROR: ['LCCCR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:26:12,168 - ERROR: $LEGO+: possibly delisted; no timezone found
# 2026-07-09 19:26:12,186 - ERROR:
# 1 Failed download:
# 2026-07-09 19:26:12,196 - ERROR: ['LEGO+']: possibly delisted; no timezone found
# 2026-07-09 19:26:17,777 - ERROR: LFACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:26:17,788 - ERROR:
# 1 Failed download:
# 2026-07-09 19:26:17,789 - ERROR: ['LFACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:26:44,211 - ERROR: LKSPR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:26:44,224 - ERROR:
# 1 Failed download:
# 2026-07-09 19:26:44,229 - ERROR: ['LKSPR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:27:06,057 - ERROR: LPCVW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:27:06,090 - ERROR:
# 1 Failed download:
# 2026-07-09 19:27:06,092 - ERROR: ['LPCVW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:27:37,379 - ERROR: $LVWR+: possibly delisted; no timezone found
# 2026-07-09 19:27:37,389 - ERROR:
# 1 Failed download:
# 2026-07-09 19:27:37,390 - ERROR: ['LVWR+']: possibly delisted; no timezone found
# 2026-07-09 19:27:46,722 - ERROR: $LZM+: possibly delisted; no timezone found
# 2026-07-09 19:27:46,728 - ERROR:
# 1 Failed download:
# 2026-07-09 19:27:46,729 - ERROR: ['LZM+']: possibly delisted; no timezone found
# 2026-07-09 19:28:11,771 - ERROR: MBGL: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:11,774 - ERROR:
# 1 Failed download:
# 2026-07-09 19:28:11,776 - ERROR: ['MBGL']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:20,520 - ERROR: MCAHR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:20,523 - ERROR:
# 1 Failed download:
# 2026-07-09 19:28:20,524 - ERROR: ['MCAHR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:48,215 - ERROR: MESHW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:48,222 - ERROR:
# 1 Failed download:
# 2026-07-09 19:28:48,224 - ERROR: ['MESHW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:50,869 - ERROR: METG: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:50,879 - ERROR:
# 1 Failed download:
# 2026-07-09 19:28:50,880 - ERROR: ['METG']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:52,469 - ERROR: MEVOW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:52,477 - ERROR:
# 1 Failed download:
# 2026-07-09 19:28:52,478 - ERROR: ['MEVOW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:58,826 - ERROR: MFP: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:28:58,832 - ERROR:
# 1 Failed download:
# 2026-07-09 19:28:58,833 - ERROR: ['MFP']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:29:31,112 - ERROR: MKLYR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:29:31,117 - ERROR:
# 1 Failed download:
# 2026-07-09 19:29:31,118 - ERROR: ['MKLYR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:29:33,968 - ERROR: MLAAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:29:33,971 - ERROR:
# 1 Failed download:
# 2026-07-09 19:29:33,972 - ERROR: ['MLAAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:29:51,486 - ERROR: MMTXW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:29:51,502 - ERROR:
# 1 Failed download:
# 2026-07-09 19:29:51,503 - ERROR: ['MMTXW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:30:47,316 - ERROR: $MTAL+: possibly delisted; no timezone found
# 2026-07-09 19:30:47,332 - ERROR:
# 1 Failed download:
# 2026-07-09 19:30:47,335 - ERROR: ['MTAL+']: possibly delisted; no timezone found
# 2026-07-09 19:30:54,767 - ERROR: $MTNE+: possibly delisted; no timezone found
# 2026-07-09 19:30:54,771 - ERROR:
# 1 Failed download:
# 2026-07-09 19:30:54,773 - ERROR: ['MTNE+']: possibly delisted; no timezone found
# 2026-07-09 19:31:11,049 - ERROR: MUZEW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:11,066 - ERROR:
# 1 Failed download:
# 2026-07-09 19:31:11,067 - ERROR: ['MUZEW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:30,265 - ERROR: MYXXR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:30,269 - ERROR:
# 1 Failed download:
# 2026-07-09 19:31:30,271 - ERROR: ['MYXXR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:30,738 - ERROR: MYXXW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:30,752 - ERROR:
# 1 Failed download:
# 2026-07-09 19:31:30,753 - ERROR: ['MYXXW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:32,480 - ERROR: $MZYX+: possibly delisted; no timezone found
# 2026-07-09 19:31:32,495 - ERROR:
# 1 Failed download:
# 2026-07-09 19:31:32,495 - ERROR: ['MZYX+']: possibly delisted; no timezone found
# 2026-07-09 19:31:32,991 - WARNING: Lỗi khi tải nan: 'float' object has no attribute 'replace'
# 2026-07-09 19:31:51,190 - ERROR: NBRGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:31:51,196 - ERROR:
# 1 Failed download:
# 2026-07-09 19:31:51,199 - ERROR: ['NBRGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:32:05,345 - ERROR: $NE+A: possibly delisted; no timezone found
# 2026-07-09 19:32:05,351 - ERROR:
# 1 Failed download:
# 2026-07-09 19:32:05,352 - ERROR: ['NE+A']: possibly delisted; no timezone found
# 2026-07-09 19:32:05,878 - ERROR: $NE+: possibly delisted; no timezone found
# 2026-07-09 19:32:05,884 - ERROR:
# 1 Failed download:
# 2026-07-09 19:32:05,885 - ERROR: ['NE+']: possibly delisted; no timezone found
# 2026-07-09 19:32:19,234 - ERROR: NEXRW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:32:19,248 - ERROR:
# 1 Failed download:
# 2026-07-09 19:32:19,249 - ERROR: ['NEXRW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:32:30,711 - ERROR: NHIVW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:32:30,745 - ERROR:
# 1 Failed download:
# 2026-07-09 19:32:30,746 - ERROR: ['NHIVW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:32:51,271 - ERROR: NMPAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:32:51,278 - ERROR:
# 1 Failed download:
# 2026-07-09 19:32:51,284 - ERROR: ['NMPAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:33:01,584 - ERROR: NOEMR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:33:01,601 - ERROR:
# 1 Failed download:
# 2026-07-09 19:33:01,601 - ERROR: ['NOEMR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:33:13,756 - ERROR: $NPWR+: possibly delisted; no timezone found
# 2026-07-09 19:33:13,774 - ERROR:
# 1 Failed download:
# 2026-07-09 19:33:13,777 - ERROR: ['NPWR+']: possibly delisted; no timezone found
# 2026-07-09 19:33:24,290 - ERROR: $NSIG: possibly delisted; no timezone found
# 2026-07-09 19:33:24,296 - ERROR:
# 1 Failed download:
# 2026-07-09 19:33:24,297 - ERROR: ['NSIG']: possibly delisted; no timezone found
# 2026-07-09 19:33:25,414 - ERROR: $NSIV: possibly delisted; no timezone found
# 2026-07-09 19:33:25,417 - ERROR:
# 1 Failed download:
# 2026-07-09 19:33:25,418 - ERROR: ['NSIV']: possibly delisted; no timezone found
# 2026-07-09 19:33:40,974 - ERROR: NUCLW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:33:40,983 - ERROR:
# 1 Failed download:
# 2026-07-09 19:33:40,984 - ERROR: ['NUCLW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:33:51,904 - ERROR: $NVA+: possibly delisted; no timezone found
# 2026-07-09 19:33:51,915 - ERROR:
# 1 Failed download:
# 2026-07-09 19:33:51,916 - ERROR: ['NVA+']: possibly delisted; no timezone found
# 2026-07-09 19:34:06,152 - ERROR: $NWAX+: possibly delisted; no timezone found
# 2026-07-09 19:34:06,158 - ERROR:
# 1 Failed download:
# 2026-07-09 19:34:06,159 - ERROR: ['NWAX+']: possibly delisted; no timezone found
# 2026-07-09 19:34:50,431 - ERROR: OHACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:34:50,443 - ERROR:
# 1 Failed download:
# 2026-07-09 19:34:50,444 - ERROR: ['OHACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:34:55,560 - ERROR: OIMAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:34:55,589 - ERROR:
# 1 Failed download:
# 2026-07-09 19:34:55,591 - ERROR: ['OIMAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:34:56,030 - ERROR: OIOWW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:34:56,047 - ERROR:
# 1 Failed download:
# 2026-07-09 19:34:56,048 - ERROR: ['OIOWW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:35:22,079 - ERROR: $OPFI+: possibly delisted; no timezone found
# 2026-07-09 19:35:22,084 - ERROR:
# 1 Failed download:
# 2026-07-09 19:35:22,085 - ERROR: ['OPFI+']: possibly delisted; no timezone found
# 2026-07-09 19:36:01,771 - ERROR: $OXY+: possibly delisted; no timezone found
# 2026-07-09 19:36:01,775 - ERROR:
# 1 Failed download:
# 2026-07-09 19:36:01,776 - ERROR: ['OXY+']: possibly delisted; no timezone found
# 2026-07-09 19:36:05,802 - ERROR: PAACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:36:05,819 - ERROR:
# 1 Failed download:
# 2026-07-09 19:36:05,820 - ERROR: ['PAACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:36:12,464 - ERROR: $PAII+: possibly delisted; no timezone found
# 2026-07-09 19:36:12,489 - ERROR:
# 1 Failed download:
# 2026-07-09 19:36:12,490 - ERROR: ['PAII+']: possibly delisted; no timezone found
# 2026-07-09 19:36:14,530 - ERROR: PALOW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:36:14,537 - ERROR:
# 1 Failed download:
# 2026-07-09 19:36:14,538 - ERROR: ['PALOW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:37:21,745 - ERROR: PECER: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:37:21,751 - ERROR:
# 1 Failed download:
# 2026-07-09 19:37:21,752 - ERROR: ['PECER']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:37:22,571 - ERROR: PECEW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:37:22,575 - ERROR:
# 1 Failed download:
# 2026-07-09 19:37:22,575 - ERROR: ['PECEW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:37:38,390 - ERROR: $PEW+: possibly delisted; no timezone found
# 2026-07-09 19:37:38,396 - ERROR:
# 1 Failed download:
# 2026-07-09 19:37:38,397 - ERROR: ['PEW+']: possibly delisted; no timezone found
# 2026-07-09 19:37:55,108 - ERROR: PGACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:37:55,119 - ERROR:
# 1 Failed download:
# 2026-07-09 19:37:55,119 - ERROR: ['PGACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:38:41,899 - ERROR: $PMA: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:38:41,914 - ERROR:
# 1 Failed download:
# 2026-07-09 19:38:41,916 - ERROR: ['PMA']: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:39:09,040 - ERROR: PONOR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:39:09,051 - ERROR:
# 1 Failed download:
# 2026-07-09 19:39:09,051 - ERROR: ['PONOR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:05,466 - ERROR: $PSQH+: possibly delisted; no timezone found
# 2026-07-09 19:40:05,474 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:05,474 - ERROR: ['PSQH+']: possibly delisted; no timezone found
# 2026-07-09 19:40:09,741 - ERROR: $PTACW: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:40:09,772 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:09,773 - ERROR: ['PTACW']: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:40:17,515 - ERROR: PTORW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:17,528 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:17,530 - ERROR: ['PTORW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:27,840 - ERROR: PWRZ: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:27,855 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:27,855 - ERROR: ['PWRZ']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:39,154 - ERROR: QADRW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:39,161 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:39,163 - ERROR: ['QADRW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:51,678 - ERROR: QETAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:51,684 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:51,685 - ERROR: ['QETAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:40:59,522 - ERROR: $QLEP+: possibly delisted; no timezone found
# 2026-07-09 19:40:59,527 - ERROR:
# 1 Failed download:
# 2026-07-09 19:40:59,527 - ERROR: ['QLEP+']: possibly delisted; no timezone found
# 2026-07-09 19:41:17,727 - ERROR: QSEAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:17,743 - ERROR:
# 1 Failed download:
# 2026-07-09 19:41:17,745 - ERROR: ['QSEAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:28,884 - ERROR: QUMSR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:28,889 - ERROR:
# 1 Failed download:
# 2026-07-09 19:41:28,890 - ERROR: ['QUMSR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:37,157 - ERROR: $RAC+: possibly delisted; no timezone found
# 2026-07-09 19:41:37,172 - ERROR:
# 1 Failed download:
# 2026-07-09 19:41:37,180 - ERROR: ['RAC+']: possibly delisted; no timezone found
# 2026-07-09 19:41:41,433 - ERROR: RANGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:41,448 - ERROR:
# 1 Failed download:
# 2026-07-09 19:41:41,449 - ERROR: ['RANGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:56,671 - ERROR: RDACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:41:56,676 - ERROR:
# 1 Failed download:
# 2026-07-09 19:41:56,677 - ERROR: ['RDACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:42:23,192 - ERROR: RFAIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:42:23,199 - ERROR:
# 1 Failed download:
# 2026-07-09 19:42:23,199 - ERROR: ['RFAIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:42:23,768 - ERROR: RFAMR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:42:23,775 - ERROR:
# 1 Failed download:
# 2026-07-09 19:42:23,775 - ERROR: ['RFAMR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:42:38,390 - ERROR: RIBBR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:42:38,398 - ERROR:
# 1 Failed download:
# 2026-07-09 19:42:38,399 - ERROR: ['RIBBR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:43:29,935 - ERROR: RREVW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:43:29,947 - ERROR:
# 1 Failed download:
# 2026-07-09 19:43:29,947 - ERROR: ['RREVW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:44:14,108 - ERROR: SAAQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:44:14,120 - ERROR:
# 1 Failed download:
# 2026-07-09 19:44:14,121 - ERROR: ['SAAQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:44:16,629 - ERROR: $SAC+: possibly delisted; no timezone found
# 2026-07-09 19:44:16,637 - ERROR:
# 1 Failed download:
# 2026-07-09 19:44:16,637 - ERROR: ['SAC+']: possibly delisted; no timezone found
# 2026-07-09 19:44:19,829 - ERROR: $SAGU+: possibly delisted; no timezone found
# 2026-07-09 19:44:19,833 - ERROR:
# 1 Failed download:
# 2026-07-09 19:44:19,836 - ERROR: ['SAGU+']: possibly delisted; no timezone found
# 2026-07-09 19:44:42,164 - ERROR: $SBXD+: possibly delisted; no timezone found
# 2026-07-09 19:44:42,175 - ERROR:
# 1 Failed download:
# 2026-07-09 19:44:42,175 - ERROR: ['SBXD+']: possibly delisted; no timezone found
# 2026-07-09 19:44:42,886 - ERROR: $SBXE+: possibly delisted; no timezone found
# 2026-07-09 19:44:42,904 - ERROR:
# 1 Failed download:
# 2026-07-09 19:44:42,905 - ERROR: ['SBXE+']: possibly delisted; no timezone found
# 2026-07-09 19:44:58,043 - ERROR: SCIIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:44:58,058 - ERROR:
# 1 Failed download:
# 2026-07-09 19:44:58,059 - ERROR: ['SCIIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:45:04,845 - ERROR: SCPQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:45:04,848 - ERROR:
# 1 Failed download:
# 2026-07-09 19:45:04,850 - ERROR: ['SCPQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:45:11,614 - ERROR: SDHIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:45:11,632 - ERROR:
# 1 Failed download:
# 2026-07-09 19:45:11,633 - ERROR: ['SDHIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:45:30,666 - ERROR: $SES+: possibly delisted; no timezone found
# 2026-07-09 19:45:30,679 - ERROR:
# 1 Failed download:
# 2026-07-09 19:45:30,681 - ERROR: ['SES+']: possibly delisted; no timezone found
# 2026-07-09 19:46:36,292 - ERROR: SKYAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:46:36,301 - ERROR:
# 1 Failed download:
# 2026-07-09 19:46:36,302 - ERROR: ['SKYAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:46:37,746 - ERROR: $SKYH+: possibly delisted; no timezone found
# 2026-07-09 19:46:37,762 - ERROR:
# 1 Failed download:
# 2026-07-09 19:46:37,764 - ERROR: ['SKYH+']: possibly delisted; no timezone found
# 2026-07-09 19:46:50,591 - ERROR: $SLND+: possibly delisted; no timezone found
# 2026-07-09 19:46:50,599 - ERROR:
# 1 Failed download:
# 2026-07-09 19:46:50,600 - ERROR: ['SLND+']: possibly delisted; no timezone found
# 2026-07-09 19:46:57,526 - ERROR: $SLVY: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:46:57,538 - ERROR:
# 1 Failed download:
# 2026-07-09 19:46:57,539 - ERROR: ['SLVY']: possibly delisted; no price data found  (1d 1927-08-03 -> 2026-07-09)
# 2026-07-09 19:47:46,906 - ERROR: SORNW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:47:46,912 - ERROR:
# 1 Failed download:
# 2026-07-09 19:47:46,913 - ERROR: ['SORNW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:00,945 - ERROR: SPEGR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:00,955 - ERROR:
# 1 Failed download:
# 2026-07-09 19:48:00,955 - ERROR: ['SPEGR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:50,065 - ERROR: SSACR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:50,070 - ERROR:
# 1 Failed download:
# 2026-07-09 19:48:50,071 - ERROR: ['SSACR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:50,441 - ERROR: SSACW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:50,455 - ERROR:
# 1 Failed download:
# 2026-07-09 19:48:50,456 - ERROR: ['SSACW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:52,674 - ERROR: SSEAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:48:52,679 - ERROR:
# 1 Failed download:
# 2026-07-09 19:48:52,680 - ERROR: ['SSEAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:29,786 - ERROR: SUMAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:29,790 - ERROR:
# 1 Failed download:
# 2026-07-09 19:49:29,792 - ERROR: ['SUMAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:38,537 - ERROR: SVAQW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:38,551 - ERROR:
# 1 Failed download:
# 2026-07-09 19:49:38,551 - ERROR: ['SVAQW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:40,620 - ERROR: SVIVW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:40,637 - ERROR:
# 1 Failed download:
# 2026-07-09 19:49:40,639 - ERROR: ['SVIVW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:58,672 - ERROR: SZZLR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:49:58,687 - ERROR:
# 1 Failed download:
# 2026-07-09 19:49:58,688 - ERROR: ['SZZLR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:50:11,084 - ERROR: TAVIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:50:11,099 - ERROR:
# 1 Failed download:
# 2026-07-09 19:50:11,100 - ERROR: ['TAVIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:51:04,858 - ERROR: TDWDR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:51:04,868 - ERROR:
# 1 Failed download:
# 2026-07-09 19:51:04,869 - ERROR: ['TDWDR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:51:32,683 - ERROR: $TGE+: possibly delisted; no timezone found
# 2026-07-09 19:51:32,691 - ERROR:
# 1 Failed download:
# 2026-07-09 19:51:32,693 - ERROR: ['TGE+']: possibly delisted; no timezone found
# 2026-07-09 19:52:19,701 - ERROR: TMSWW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:52:19,713 - ERROR:
# 1 Failed download:
# 2026-07-09 19:52:19,713 - ERROR: ['TMSWW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:52:20,284 - ERROR: TMTSW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:52:20,290 - ERROR:
# 1 Failed download:
# 2026-07-09 19:52:20,290 - ERROR: ['TMTSW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:52:51,709 - ERROR: TRGSR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:52:51,712 - ERROR:
# 1 Failed download:
# 2026-07-09 19:52:51,713 - ERROR: ['TRGSR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:53:19,783 - ERROR: TRUM: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:53:19,797 - ERROR:
# 1 Failed download:
# 2026-07-09 19:53:19,797 - ERROR: ['TRUM']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:53:20,717 - ERROR: TRUN: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:53:20,728 - ERROR:
# 1 Failed download:
# 2026-07-09 19:53:20,734 - ERROR: ['TRUN']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:53:25,391 - ERROR: TRUU: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:53:25,407 - ERROR:
# 1 Failed download:
# 2026-07-09 19:53:25,417 - ERROR: ['TRUU']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:54:07,728 - ERROR: TVAIR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:54:07,760 - ERROR:
# 1 Failed download:
# 2026-07-09 19:54:07,761 - ERROR: ['TVAIR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:54:13,725 - ERROR: TWLVR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:54:13,739 - ERROR:
# 1 Failed download:
# 2026-07-09 19:54:13,740 - ERROR: ['TWLVR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:54:29,620 - ERROR: $UAC+: possibly delisted; no timezone found
# 2026-07-09 19:54:29,630 - ERROR:
# 1 Failed download:
# 2026-07-09 19:54:29,637 - ERROR: ['UAC+']: possibly delisted; no timezone found
# 2026-07-09 19:54:37,947 - ERROR: UCFIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:54:37,964 - ERROR:
# 1 Failed download:
# 2026-07-09 19:54:37,965 - ERROR: ['UCFIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:55:06,368 - ERROR: UN: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:55:06,409 - ERROR:
# 1 Failed download:
# 2026-07-09 19:55:06,410 - ERROR: ['UN']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:56:01,113 - ERROR: UYSCR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:56:01,119 - ERROR:
# 1 Failed download:
# 2026-07-09 19:56:01,120 - ERROR: ['UYSCR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:56:04,959 - ERROR: $VACI+: possibly delisted; no timezone found
# 2026-07-09 19:56:04,976 - ERROR:
# 1 Failed download:
# 2026-07-09 19:56:04,977 - ERROR: ['VACI+']: possibly delisted; no timezone found
# 2026-07-09 19:56:06,049 - ERROR: $VAL+: possibly delisted; no timezone found
# 2026-07-09 19:56:06,066 - ERROR:
# 1 Failed download:
# 2026-07-09 19:56:06,067 - ERROR: ['VAL+']: possibly delisted; no timezone found
# 2026-07-09 19:56:45,528 - ERROR: VHCPW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:56:45,535 - ERROR:
# 1 Failed download:
# 2026-07-09 19:56:45,536 - ERROR: ['VHCPW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:57:01,775 - ERROR: $VLN+: possibly delisted; no timezone found
# 2026-07-09 19:57:01,789 - ERROR:
# 1 Failed download:
# 2026-07-09 19:57:01,790 - ERROR: ['VLN+']: possibly delisted; no timezone found
# 2026-07-09 19:57:34,155 - ERROR: VRXAW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:57:34,158 - ERROR:
# 1 Failed download:
# 2026-07-09 19:57:34,160 - ERROR: ['VRXAW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:59:18,443 - ERROR: WLIIW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:59:18,447 - ERROR:
# 1 Failed download:
# 2026-07-09 19:59:18,448 - ERROR: ['WLIIW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:59:41,495 - ERROR: WSTNR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:59:41,508 - ERROR:
# 1 Failed download:
# 2026-07-09 19:59:41,509 - ERROR: ['WSTNR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:59:44,611 - ERROR: WTGUR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 19:59:44,620 - ERROR:
# 1 Failed download:
# 2026-07-09 19:59:44,621 - ERROR: ['WTGUR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:00:06,684 - ERROR: XCBEW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:00:06,687 - ERROR:
# 1 Failed download:
# 2026-07-09 20:00:06,689 - ERROR: ['XCBEW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:00:57,997 - ERROR: XRXDW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:00:58,033 - ERROR:
# 1 Failed download:
# 2026-07-09 20:00:58,043 - ERROR: ['XRXDW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:01:00,399 - ERROR: XSLLW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:01:00,412 - ERROR:
# 1 Failed download:
# 2026-07-09 20:01:00,414 - ERROR: ['XSLLW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:01:33,897 - ERROR: $YCY+: possibly delisted; no timezone found
# 2026-07-09 20:01:33,912 - ERROR:
# 1 Failed download:
# 2026-07-09 20:01:33,914 - ERROR: ['YCY+']: possibly delisted; no timezone found
# 2026-07-09 20:01:51,085 - ERROR: YHNAR: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:01:51,092 - ERROR:
# 1 Failed download:
# 2026-07-09 20:01:51,092 - ERROR: ['YHNAR']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:02:23,254 - ERROR: ZKPW: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:02:23,259 - ERROR:
# 1 Failed download:
# 2026-07-09 20:02:23,260 - ERROR: ['ZKPW']: Period 'max' is invalid, must be one of: 1d, 5d
# 2026-07-09 20:02:34,915 - INFO: Đang cập nhật Metadata các mã thành công...
# 2026-07-09 20:02:35,011 - INFO: Hoàn tất! Đã tải thành công 12224 file vào thư mục Raw.
